# %%
import pandas as pd
Y = pd.read_csv("titanic.csv")
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
missing_values = task.isnull().sum()
missing_values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
task.value_counts(["Survived"])
# Out:
# Survived
# 0           549
# 1           342
# Name: count, dtype: int64

# %%
Y= task["Survived"].mean()*100
Y
# Out:
# np.float64(38.38383838383838)

# %%
Y= task.dropna(subset=['Age'])
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(Y['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0370111d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c037011450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c037011090>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c0370116d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c037011810>],
#  'means': []}

# %%
#check missing values
mode = task["Embarked"].mode()
mode
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
#Filling in missing values
task["Embarked"]=task["Embarked"].fillna(mode)
task["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
task.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
Y = Y.drop(columns=["Cabin"], axis=1)
print(Y)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Pclass", hue="Survived", data=Y)
plt.title("Survival count by class")
plt.xlabel("Passenger class")
plt.ylabel("Count")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Pclass", hue="Embarked", data=Y)
plt.title("Passengers carried")
plt.xlabel("Passenger class")
plt.ylabel("Embarked")
plt.show()

# %%
Y = Y.drop(columns=["Ticket",], axis=1)
print(Y)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Y = Y.drop(columns=["PassengerId"], axis=1)
print(Y)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
Y
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
Y["Family Size"] = Y["Parch"] + Y["SibSp"]+1
Y
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked  Family Size
# ...

# %%
Y = Y.drop(columns=["SibSp"], axis=1)
print(Y)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  Parch     Fare Embarked  Family Size
# ...

# %%
Y = Y.drop(columns=["Parch"], axis=1)
print(Y)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age     Fare Embarked  Family Size
# ...

# %%
Y
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age     Fare Embarked  Family Size
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Family Size", hue="Survived", data=Y)
plt.title("Survival count by Family Size")
plt.xlabel("family size")
plt.ylabel("Count")
plt.show()

# %%
Y.value_counts(Y["Family Size"])
# Out:
# Family Size
# 1    404
# 2    139
# 3     93
# 4     27
# 6     22
# 7     12
# 5     11
# 8      6
# Name: count, dtype: int64

# %%
#Adding Fare Group to the dataset
Y = pd.read_csv("titanic.csv")
if "Fare" in Y.columns:
    Y['fare'] = pd.to_numeric(Y['Fare'], errors='coerce')
    fare_bins = [0, 20, 50, 100, 200, float('inf')]
    fare_labels = ['Low', 'Lower-Middle', 'middle', 'Upper-Middle', 'High' ]
    Y['Fare Group'] = pd.cut(Y['Fare']+1, bins=fare_bins, labels=fare_labels, include_lowest=True)
    print(Y[['PassengerId', 'Fare', 'Fare Group']].head())
    Y.to_csv('updated_titanic.csv', index=False)
else:
    print("NO 'Fare' column found in dataset")
# Out:
#    PassengerId     Fare Fare Group
# 0            1   7.2500        Low
# 1            2  71.2833     middle
# 2            3   7.9250        Low
# 3            4  53.1000     middle
# 4            5   8.0500        Low

# %%
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Categorizing passengers into Age Groups
data = {'PassengerId': [1,2,3,4,5], 'Age': [5,16,25,45,70]}
bins = [0,12,19,59, float('inf')]
labels = ['Children', 'Teenagers', 'Adults', 'Seniors']
Y['Age Group'] = pd.cut(Y['Age'], bins=bins, labels=labels, right=True)
print(Y)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Age Group", hue="Survived", data=Y)
plt.title("Survival count by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Survival")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Age Group", hue="Survived", data=Y)
plt.title("Survival count by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Survival")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Title", hue="Survived", data=Y)
plt.title("Survival count by Title")
plt.xlabel("Title")
plt.ylabel("Survival")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Pclass", hue="Survived", data=Y)
plt.title("Survival count by Age Group")
plt.xlabel("Pclass")
plt.ylabel("Fare")
plt.show()

# %%
# extracting title from name
Y = pd.read_csv('titanic.csv')
Y['Title'] = Y['Name'].str.extract(r",\s(\w+)\.")
print("\nUnique titles in dataset")
print(Y["Title"].unique())
title_survival = Y.groupby("Title")["Survived"].mean()
print("\nSurvival rates by title:")
print(title_survival)
# Out:
# Unique titles in dataset
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' nan 'Jonkheer']
#
# Survival rates by title:
# Title
# Capt        0.000000
# Col         0.500000
# Don         0.000000
# Dr          0.428571
# Jonkheer    0.000000
# Lady        1.000000
# Major       0.500000
# Master      0.575000
# Miss        0.697802
# Mlle        1.000000
# Mme         1.000000
# Mr          0.156673
# Mrs         0.792000
# Ms          1.000000
# Rev         0.000000
# Sir         1.000000
# Name: Survived, dtype: float64

# %%
Y
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
